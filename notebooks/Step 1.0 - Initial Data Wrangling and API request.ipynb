# %% [markdown]
# # Accessing ProPublica API and Converting Form 990 Information to Pandas Dataframes #

# %%
import requests
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# #### The function below will access the ProPublica API and return all nonprofit entities with the provided query string in the organization title and the National Taxonomy of Exempt Entities (NTEE) code. More information on NTEE codes is available here:####
# https://learn.guidestar.org/help/ntee-codes

# %% [markdown]
# #### Documentation of the ProPublica API is available here: ####
# https://projects.propublica.org/nonprofits/api

# %%
def ProPublica_API_access (query_string, ntee_code):
    """
    This function retrieves organizations from the ProPublica API matching a given query string, i.e. 'opera', 'symphony', etc.
    
    Args:
    query_string (str): A query string that must be a part of the name of each organization that is returned.
    ntee_code (str): The National Taxonomy of Exempt Entities (NTEE) code
    
    Returns:
    A Pandas dataframe 
    """
    
    url = 'https://projects.propublica.org/nonprofits/api/v2/search.json?q='+query_string
    organizations = []
    for x in range(11):
        params = dict(q=query_string, page=x)
        request = requests.get(url, params=params)
        json = request.json()
        json.pop('total_results')
        page_of_orgs = json.pop('organizations')
        organizations.append(page_of_orgs)
    global df
    df = pd.DataFrame()
    for x in tqdm(range(len(organizations))):
        for y in range(len(organizations[x])):
            org = organizations[x][y]
            df = df.append(org,ignore_index=True)
    #This step will fix typos in the 'ntee_code' column#
    df['ntee_code'].fillna(ntee_code,inplace=True)
    df[df['ntee_code'].str.contains(ntee_code)]
    #This step sets the organization's EIN as the index#
    df['ein'] = df['ein'].astype('int')
    df = df.set_index('ein')
    return df.head()

# %%
ProPublica_API_access('opera','A6A')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:08<00:00,  1.34it/s]
#                 city  has_subseccd have_extracts have_filings have_pdfs  \
# ein
# 813311094    ASTORIA           1.0          None         None      None
# 263016871  LEXINGTON           1.0          None         None      None
# 833139772    SUNLAND           1.0          None         None      None
# 462541609       BEND           1.0          None         None      None
# 840850527  ENGLEWOOD           1.0          None         None      None
#
#                       name ntee_code raw_ntee_code     score   state  \
# ein
# 813311094       BARE OPERA       A6A           A6A  8022.336      NY
# 263016871  BLUEGRASS OPERA       A6A           A6A  8022.336      KY
# 833139772    MISSION OPERA       A6A           A6A  8022.336      CA
# 462541609       OPERA BEND       A99           A99  8022.336  Oregon
# 840850527   OPERA COLORADO      A6A0          A6A0  8022.336      CO
#
#                strein         sub_name  subseccd
# ein
# 813311094  81-3311094       BARE OPERA       3.0
# 263016871  26-3016871  BLUEGRASS OPERA       3.0
# 833139772  83-3139772    MISSION OPERA       3.0
# 462541609  46-2541609       OPERA BEND       3.0
# 840850527  84-0850527   OPERA COLORADO       3.0

# %%
df['strein'] = df['strein'].str.replace('-','')
df['strein'] = pd.to_numeric(df['strein'], errors = 'coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-4f79773b976b> in <module>
# ----> 1 df['strein'] = df['strein'].str.replace('-','')
#       2 df['strein'] = pd.to_numeric(df['strein'], errors = 'coerce')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    1915
#    1916     def __init__(self, data):
# -> 1917         self._inferred_dtype = self._validate(data)
#    1918         self._is_categorical = is_categorical_dtype(data)
#    1919
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    1965
#    1966         if inferred_dtype not in allowed_types:
# -> 1967             raise AttributeError("Can only use .str accessor with string " "values!")
#    1968         return inferred_dtype
#    1969
#
# AttributeError: Can only use .str accessor with string values!

# %%
eins = df.index.values.tolist()
eins
# Out:
# [813311094,
#  263016871,
#  833139772,
#  462541609,
#  840850527,
#  464332937,
#  453361602,
#  222519789,
#  800432320,
#  824079263,
#  237314812,
#  850391704,
#  821536854,
#  824602315,
#  910760426,
#  752253647,
#  364454720,
#  463486730,
#  814363604,
#  260006536,
#  953854105,
#  566019660,
#  432032363,
#  231504706,
#  133819493,
#  522175213,
#  20484003,
#  462223000,
#  930679959,
#  475311222,
#  471255941,
#  237207572,
#  454913985,
#  203975320,
#  10496860,
#  541618192,
#  952224201,
#  943068290,
#  726021455,
#  200156714,
#  824935291,
#  952503791,
#  954512214,
#  463142361,
#  50453691,
#  510213334,
#  571129329,
#  411375724,
#  680454224,
#  263649993,
#  756004746,
#  522001426,
#  471571156,
#  721584393,
#  222270100,
#  270940187,
#  920148120,
#  237169261,
#  832435880,
#  954868027,
#  262584694,
#  341816013,
#  811599946,
#  770668548,
#  463775780,
#  223954352,
#  475324014,
#  942495701,
#  990197758,
#  263346265,
#  261577184,
#  461846033,
#  833135996,
#  260348842,
#  821447688,
#  270813566,
#  382052726,
#  272295236,
#  621119830,
#  886009267,
#  942985556,
#  203520577,
#  300540629,
#  133098404,
#  460758350,
#  421671038,
#  270406958,
#  811027258,
#  475537607,
#  464229833,
#  237257400,
#  141897871,
#  204618904,
#  953566332,
#  821734082,
#  475593869,
#  822992437,
#  841960658,
#  730643311,
#  202980771,
#  811227880,
#  30297488,
#  562167677,
#  204377736,
#  842415389,
#  310549044,
#  201061074,
#  454333621,
#  474324060,
#  463016862,
#  262068879,
#  462588285,
#  273442010,
#  364477750,
#  465133609,
#  236392136,
#  362935678,
#  461051323,
#  462353777,
#  636045261,
#  202533756,
#  510238088,
#  760792196,
#  386142941,
#  271588801,
#  237043885,
#  310996184,
#  421511984,
#  261789005,
#  880439165,
#  261151492,
#  620785544,
#  161582367,
#  770503778,
#  421521354,
#  510163755,
#  320471175,
#  251073139,
#  942418029,
#  842879548,
#  275377856,
#  562339957,
#  911174712,
#  824395014,
#  454776069,
#  223190959,
#  133874026,
#  463086770,
#  942739808,
#  454562793,
#  810931917,
#  510175124,
#  920175714,
#  742390496,
#  453327080,
#  263688025,
#  473126062,
#  263671215,
#  812861492,
#  341184816,
#  823081872,
#  202525282,
#  831258247,
#  470989874,
#  461509400,
#  474122815,
#  843056020,
#  351405179,
#  43008633,
#  472981461,
#  814429775,
#  42756974,
#  841287161,
#  61327606,
#  516018055,
#  752429448,
#  452988644,
#  161634500,
#  201327526,
#  113469561,
#  134007378,
#  465221737,
#  541759573,
#  261789196,
#  222325828,
#  953426868,
#  136071129,
#  861171749,
#  237321992,
#  203916548,
#  260018625,
#  237025084,
#  61714846,
#  133823577,
#  133219847,
#  61633557,
#  856012246,
#  341874951,
#  42621713,
#  60963170,
#  931304008,
#  411368101,
#  823377744,
#  237437382,
#  207530206,
#  470842288,
#  821384455,
#  30341456,
#  262039839,
#  113224934,
#  311566849,
#  311566854,
#  133571240,
#  381742032,
#  263658231,
#  133801738,
#  721476675,
#  311566860,
#  462344098,
#  113093248,
#  263969962,
#  363652212,
#  421354260,
#  426064252,
#  364621785,
#  680626679,
#  861029738,
#  43467601,
#  956220739,
#  461049598,
#  841201337,
#  823293332,
#  371608158,
#  311566863,
#  311566868,
#  822220394,
#  367033135,
#  416429970,
#  651223761,
#  411821299,
#  521830370,
#  843534175,
#  472574201,
#  586217462,
#  953760983,
#  522280975,
#  300260223,
#  134147698,
#  460551184,
#  362796630,
#  462294622,
#  251431049,
#  391967766,
#  20662241,
#  931191876,
#  611796573,
#  30353647,
#  133311277,
#  870469002,
#  911428888,
#  112745438,
#  474468309,
#  237039510,
#  586162874]

# %%
url2 = 'https://projects.propublica.org/nonprofits/api/v2/organizations/{}.json'.format(840850527)
request2 = requests.get(url2)
json2 = request2.json()
json2
# Out:
# {'organization': {'id': 840850527,
#   'ein': 840850527,
#   'name': 'OPERA COLORADO',
#   'careofname': None,
#   'address': '4121 S NAVAJO ST STE 100',
#   'city': 'ENGLEWOOD',
#   'state': 'CO',
#   'zipcode': '80110-4479',
#   'exemption_number': 0,
#   'subsection_code': 3,
#   'affiliation_code': 3,
#   'classification_codes': '1200',
#   'ruling_date': '1981-11-01',
#   'deductibility_code': 1,
#   'foundation_code': 15,
#   'activity_codes': '090000000',
#   'organization_code': 1,
#   'exempt_organization_status_code': 1,
#   'tax_period': '2019-06-01',
#   'asset_code': 6,
#   'income_code': 7,
#   'filing_requirement_code': 1,
#   'pf_filing_requirement_code': 0,
#   'accounting_period': 6,
#   'asset_amount': 2438450,
#   'income_amount': 5176971,
#   'revenue_amount': 5047106,
#   'ntee_code': 'A6A0',
#   'sort_name': None,
#   'created_at': '2020-06-16T00:21:58.641Z',
#   'updated_at': '2020-06-16T00:21:58.641Z',
#   'data_source': None,
#   'have_extracts': None,
#   'have_pdfs': None},
#  'filings_with_data': [{'tax_prd': 201806,
#    'tax_prd_yr': 2018,
#    'formtype': 0,
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=02_2019_prefixes_84-90%2F840850527_201806_990_2019020116054994.pdf',
#    'updated': '2019-10-15T18:35:57.330Z',
#    'totrevenue': 4123180,
#    'totfuncexpns': 4426594,
#    'totassetsend': 2069154,
#    'totliabend': 2048030,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 3,
#    'unrelbusinccd': 'Y',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 2792062,
#    'totprgmrevnue': 1385097,
#    'invstmntinc': 91,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 12107,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 12107,
#    'rntlincprsnl': 0,
#    'netrntlinc': 12107,
#    'grsalesecur': 0,
#    'grsalesothr': 0,
#    'cstbasisecur': 56,
#    'cstbasisothr': 0,
#    'gnlsecur': -56,
#    'gnlsothr': 0,
#    'netgnls': -56,
#    'grsincfndrsng': 46984,
#    'lessdirfndrsng': 120138,
#    'netincfndrsng': -73154,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 7033,
#    'compnsatncurrofcr': 290481,
#    'othrsalwages': 2228570,
#    'payrolltx': 163103,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 763000,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': 21124,
#    'nonpfrea': '7',
#    'gftgrntsrcvd170': 11456578,
#    'txrevnuelevied170': 1273192,
#    'srvcsval170': 0,
#    'grsinc170': 13310,
#    'grsrcptsrelated170': 5715309,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527},
#   {'tax_prd': 201706,
#    'tax_prd_yr': 2017,
#    'formtype': 0,
#    'pdf_url': None,
#    'updated': '2019-10-15T18:35:57.330Z',
#    'totrevenue': 3886779,
#    'totfuncexpns': 4098622,
#    'totassetsend': 1139309,
#    'totliabend': 814771,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 3,
#    'unrelbusinccd': 'N',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 2794543,
#    'totprgmrevnue': 1004983,
#    'invstmntinc': 2631,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 0,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 0,
#    'rntlincprsnl': 0,
#    'netrntlinc': 0,
#    'grsalesecur': 0,
#    'grsalesothr': 55000,
#    'cstbasisecur': 0,
#    'cstbasisothr': 32682,
#    'gnlsecur': 0,
#    'gnlsothr': 22318,
#    'netgnls': 22318,
#    'grsincfndrsng': 97055,
#    'lessdirfndrsng': 97055,
#    'netincfndrsng': 0,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 62304,
#    'compnsatncurrofcr': 273406,
#    'othrsalwages': 967578,
#    'payrolltx': 125810,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 200000,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': 324538,
#    'nonpfrea': '7',
#    'gftgrntsrcvd170': 12486203,
#    'txrevnuelevied170': 1280944,
#    'srvcsval170': 0,
#    'grsinc170': 872,
#    'grsrcptsrelated170': 5522605,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527},
#   {'tax_prd': 201606,
#    'tax_prd_yr': 2016,
#    'formtype': 0,
#    'pdf_url': None,
#    'updated': '2018-12-10T23:11:24.431Z',
#    'totrevenue': 3801655,
#    'totfuncexpns': 3661733,
#    'totassetsend': 1410507,
#    'totliabend': 874126,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 3,
#    'unrelbusinccd': 'N',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 2638234,
#    'totprgmrevnue': 1122287,
#    'invstmntinc': 91,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 0,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 0,
#    'rntlincprsnl': 0,
#    'netrntlinc': 0,
#    'grsalesecur': 0,
#    'grsalesothr': 0,
#    'cstbasisecur': 973,
#    'cstbasisothr': 0,
#    'gnlsecur': -973,
#    'gnlsothr': 0,
#    'netgnls': -973,
#    'grsincfndrsng': 235137,
#    'lessdirfndrsng': 235137,
#    'netincfndrsng': 0,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 42016,
#    'compnsatncurrofcr': 264451,
#    'othrsalwages': 724424,
#    'payrolltx': 94978,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 0,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': 536381,
#    'nonpfrea': '7',
#    'gftgrntsrcvd170': 12425319,
#    'txrevnuelevied170': 1338002,
#    'srvcsval170': 0,
#    'grsinc170': -1764,
#    'grsrcptsrelated170': 5414233,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527},
#   {'tax_prd': 201506,
#    'tax_prd_yr': 2015,
#    'formtype': 0,
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2016_07_EO%2F84-0850527_990_201506.pdf',
#    'updated': '2017-06-30T00:37:46.252Z',
#    'totrevenue': 3162854,
#    'totfuncexpns': 3112288,
#    'totassetsend': 1106699,
#    'totliabend': 710240,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 3,
#    'unrelbusinccd': 'N',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 1985511,
#    'totprgmrevnue': 1140273,
#    'invstmntinc': 0,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 0,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 0,
#    'rntlincprsnl': 0,
#    'netrntlinc': 0,
#    'grsalesecur': 0,
#    'grsalesothr': 0,
#    'cstbasisecur': 0,
#    'cstbasisothr': 0,
#    'gnlsecur': 0,
#    'gnlsothr': 0,
#    'netgnls': 0,
#    'grsincfndrsng': 77914,
#    'lessdirfndrsng': 77914,
#    'netincfndrsng': 0,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 37070,
#    'compnsatncurrofcr': 218074,
#    'othrsalwages': 579856,
#    'payrolltx': 88714,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 90000,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': 396459,
#    'nonpfrea': '7',
#    'gftgrntsrcvd170': 12165620,
#    'txrevnuelevied170': 1374911,
#    'srvcsval170': 0,
#    'grsinc170': -1848,
#    'grsrcptsrelated170': 6191806,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527},
#   {'tax_prd': 201406,
#    'tax_prd_yr': 2014,
#    'formtype': 0,
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2014_11_EO%2F84-0850527_990_201406.pdf',
#    'updated': '2017-06-30T00:05:09.677Z',
#    'totrevenue': 3627994,
#    'totfuncexpns': 2932649,
#    'totassetsend': 1281230,
#    'totliabend': 935337,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 3,
#    'unrelbusinccd': 'N',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 2525039,
#    'totprgmrevnue': 1062669,
#    'invstmntinc': 0,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 0,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 0,
#    'rntlincprsnl': 0,
#    'netrntlinc': 0,
#    'grsalesecur': 0,
#    'grsalesothr': 0,
#    'cstbasisecur': 0,
#    'cstbasisothr': 0,
#    'gnlsecur': 0,
#    'gnlsothr': 0,
#    'netgnls': 0,
#    'grsincfndrsng': 101075,
#    'lessdirfndrsng': 101075,
#    'netincfndrsng': 0,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 40286,
#    'compnsatncurrofcr': 212727,
#    'othrsalwages': 519292,
#    'payrolltx': 74916,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 280000,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': 345893,
#    'nonpfrea': '7',
#    'gftgrntsrcvd170': 13309338,
#    'txrevnuelevied170': 1365387,
#    'srvcsval170': 0,
#    'grsinc170': -2587,
#    'grsrcptsrelated170': 6581736,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527},
#   {'tax_prd': 201306,
#    'tax_prd_yr': 2013,
#    'formtype': 0,
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2013_12_EO%2F84-0850527_990_201306.pdf',
#    'updated': '2017-06-30T00:05:25.952Z',
#    'totrevenue': 2806519,
#    'totfuncexpns': 2873119,
#    'totassetsend': 941879,
#    'totliabend': 1291331,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 20,
#    'unrelbusinccd': 'N',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 1821250,
#    'totprgmrevnue': 960225,
#    'invstmntinc': 0,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 0,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 0,
#    'rntlincprsnl': 0,
#    'netrntlinc': 0,
#    'grsalesecur': 0,
#    'grsalesothr': 0,
#    'cstbasisecur': 0,
#    'cstbasisothr': 0,
#    'gnlsecur': 0,
#    'gnlsothr': 0,
#    'netgnls': 0,
#    'grsincfndrsng': 25898,
#    'lessdirfndrsng': 25898,
#    'netincfndrsng': 0,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 25044,
#    'compnsatncurrofcr': 127440,
#    'othrsalwages': 528527,
#    'payrolltx': 71462,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 640000,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': -349452,
#    'nonpfrea': '0',
#    'gftgrntsrcvd170': 0,
#    'txrevnuelevied170': 0,
#    'srvcsval170': 0,
#    'grsinc170': 0,
#    'grsrcptsrelated170': 0,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527},
#   {'tax_prd': 201212,
#    'tax_prd_yr': 2012,
#    'formtype': 0,
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2013_06_EO%2F84-0850527_990_201212.pdf',
#    'updated': '2017-06-29T23:49:26.840Z',
#    'totrevenue': 3600313,
#    'totfuncexpns': 4515039,
#    'totassetsend': 1499494,
#    'totliabend': 1782346,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 3,
#    'unrelbusinccd': 'N',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 2008189,
#    'totprgmrevnue': 1408017,
#    'invstmntinc': 0,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 0,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 0,
#    'rntlincprsnl': 0,
#    'netrntlinc': 0,
#    'grsalesecur': 0,
#    'grsalesothr': 0,
#    'cstbasisecur': 0,
#    'cstbasisothr': 0,
#    'gnlsecur': 0,
#    'gnlsothr': 0,
#    'netgnls': 0,
#    'grsincfndrsng': 120967,
#    'lessdirfndrsng': 120967,
#    'netincfndrsng': 0,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 184107,
#    'compnsatncurrofcr': 252749,
#    'othrsalwages': 1115424,
#    'payrolltx': 120534,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 690000,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': -282852,
#    'nonpfrea': '7',
#    'gftgrntsrcvd170': 11984132,
#    'txrevnuelevied170': 1430760,
#    'srvcsval170': 0,
#    'grsinc170': -1385,
#    'grsrcptsrelated170': 6757880,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527},
#   {'tax_prd': 201112,
#    'tax_prd_yr': 2011,
#    'formtype': 0,
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2012_06_EO%2F84-0850527_990_201112.pdf',
#    'updated': '2017-06-29T23:36:19.560Z',
#    'totrevenue': 3841457,
#    'totfuncexpns': 3740291,
#    'totassetsend': 2154609,
#    'totliabend': 1522735,
#    'pct_compnsatncurrofcr': 0.0,
#    'tax_pd': None,
#    'subseccd': 3,
#    'unrelbusinccd': 'N',
#    'initiationfees': 0,
#    'grsrcptspublicuse': 0,
#    'grsincmembers': 0,
#    'grsincother': 0,
#    'totcntrbgfts': 2785098,
#    'totprgmrevnue': 987962,
#    'invstmntinc': 0,
#    'txexmptbndsproceeds': 0,
#    'royaltsinc': 0,
#    'grsrntsreal': 0,
#    'grsrntsprsnl': 0,
#    'rntlexpnsreal': 0,
#    'rntlexpnsprsnl': 0,
#    'rntlincreal': 0,
#    'rntlincprsnl': 0,
#    'netrntlinc': 0,
#    'grsalesecur': 0,
#    'grsalesothr': 0,
#    'cstbasisecur': 0,
#    'cstbasisothr': 0,
#    'gnlsecur': 0,
#    'gnlsothr': 0,
#    'netgnls': 0,
#    'grsincfndrsng': 134640,
#    'lessdirfndrsng': 134640,
#    'netincfndrsng': 0,
#    'grsincgaming': 0,
#    'lessdirgaming': 0,
#    'netincgaming': 0,
#    'grsalesinvent': 0,
#    'lesscstofgoods': 0,
#    'netincsales': 0,
#    'miscrevtot11e': 68397,
#    'compnsatncurrofcr': 246684,
#    'othrsalwages': 994774,
#    'payrolltx': 113646,
#    'profndraising': 0,
#    'txexmptbndsend': 0,
#    'secrdmrtgsend': 430000,
#    'unsecurednotesend': 0,
#    'retainedearnend': 0,
#    'totnetassetend': 631874,
#    'nonpfrea': '7',
#    'gftgrntsrcvd170': 12563574,
#    'txrevnuelevied170': 1493703,
#    'srvcsval170': 0,
#    'grsinc170': 5791,
#    'grsrcptsrelated170': 8666021,
#    'totgftgrntrcvd509': 0,
#    'grsrcptsadmissn509': 0,
#    'txrevnuelevied509': 0,
#    'srvcsval509': 0,
#    'subtotsuppinc509': 0,
#    'totsupp509': 0,
#    'ein': 840850527}],
#  'filings_without_data': [{'tax_prd': 201906,
#    'tax_prd_yr': 2019,
#    'formtype': 0,
#    'formtype_str': '990T',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=03_2020%2F840850527_201906_990T_2020031917167709.pdf'},
#   {'tax_prd': 201012,
#    'tax_prd_yr': 2010,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2011_05_EO%2F84-0850527_990_201012.pdf'},
#   {'tax_prd': 200912,
#    'tax_prd_yr': 2009,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2010_05_EO%2F84-0850527_990_200912.pdf'},
#   {'tax_prd': 200812,
#    'tax_prd_yr': 2008,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2009_04_EO%2F84-0850527_990_200812.pdf'},
#   {'tax_prd': 200712,
#    'tax_prd_yr': 2007,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2008_04_EO%2F84-0850527_990_200712.pdf'},
#   {'tax_prd': 200512,
#    'tax_prd_yr': 2005,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2006_05_EO%2F84-0850527_990_200512.pdf'},
#   {'tax_prd': 200412,
#    'tax_prd_yr': 2004,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2005_03_EO%2F84-0850527_990_200412.pdf'},
#   {'tax_prd': 200312,
#    'tax_prd_yr': 2003,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2004_03_EO%2F84-0850527_990_200312.pdf'},
#   {'tax_prd': 200212,
#    'tax_prd_yr': 2002,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2003_06_EO%2F84-0850527_990_200212.pdf'},
#   {'tax_prd': 200112,
#    'tax_prd_yr': 2001,
#    'formtype': 0,
#    'formtype_str': '990',
#    'pdf_url': 'https://projects.propublica.org/nonprofits/download-filing?path=2002_05_EO%2F84-0850527_990_200112.pdf'}],
#  'data_source': 'ProPublica Nonprofit Explorer API: https://projects.propublica.org/nonprofits/api/\nIRS Exempt Organizations Business Master File Extract (EO BMF): https://www.irs.gov/charities-non-profits/exempt-organizations-business-master-file-extract-eo-bmf\nIRS Annual Extract of Tax-Exempt Organization Financial Data: https://www.irs.gov/uac/soi-tax-stats-annual-extract-of-tax-exempt-organization-financial-data',
#  'api_version': 2}

# %%
import time
company_ein=[]
tax_period=[]
tot_assets=[]
tot_income=[]
cont_income=[]
earned_income=[]
tot_revenue=[]
pct_compnsatncurrofcr=[]
tax_year = []
totassetsend=[]
totliabend=[]
totfuncexpns=[]
invest_income=[]
admin_expenses=[]
yearly_revenue=[]
other_revenue=[]
skipped_requests=[]
for ein in tqdm(eins):
    try:
        url2 = 'https://projects.propublica.org/nonprofits/api/v2/organizations/{}.json'.format(ein)
        request2 = requests.get(url2)
        json2 = request2.json()
        if len(json2['filings_with_data']) == 0:
            company_ein.append(ein)
            tax_period.append(json2['organization']['tax_period'])
            tot_assets.append(json2['organization']['asset_amount'])
            tot_income.append(json2['organization']['income_amount'])
            tot_revenue.append(json2['organization']['revenue_amount'])
            tax_year.append(np.nan)
            admin_expenses.append(np.nan)
            cont_income.append(np.nan)
            earned_income.append(np.nan)
            invest_income.append(np.nan)
            pct_compnsatncurrofcr.append(np.nan)
            totassetsend.append(np.nan)
            totliabend.append(np.nan)
            totfuncexpns.append(np.nan)
            yearly_revenue.append(np.nan)
            other_revenue.append(np.nan)
            time.sleep(0.5)
        else:
            for filing in range(len(json2['filings_with_data'])):
                company_ein.append(ein)
                tax_period.append(json2['organization']['tax_period'])
                tot_assets.append(json2['organization']['asset_amount'])
                tot_income.append(json2['organization']['income_amount'])
                tot_revenue.append(json2['organization']['revenue_amount'])
                tax_year.append(json2['filings_with_data'][filing]['tax_prd_yr'])
                admin_expenses.append(json2['filings_with_data'][filing]['compnsatncurrofcr'])
                cont_income.append(json2['filings_with_data'][filing]['totcntrbgfts'])
                earned_income.append(json2['filings_with_data'][filing]['totprgmrevnue'])
                invest_income.append(json2['filings_with_data'][filing]['invstmntinc'])
                pct_compnsatncurrofcr.append(json2['filings_with_data'][filing]['pct_compnsatncurrofcr'])
                totassetsend.append(json2['filings_with_data'][filing]['totassetsend'])
                totliabend.append(json2['filings_with_data'][filing]['totliabend'])
                totfuncexpns.append(json2['filings_with_data'][filing]['totfuncexpns'])
                yearly_revenue.append(json2['filings_with_data'][filing]['totrevenue'])
                other_revenue.append(json2['filings_with_data'][filing]['miscrevtot11e'])
            time.sleep(0.5)
    except:
        tax_period.append(json2['organization']['tax_period'])
        tot_assets.append(json2['organization']['asset_amount'])
        tot_income.append(json2['organization']['income_amount'])
        tot_revenue.append(json2['organization']['revenue_amount'])
        tax_year.append(np.nan)
        admin_expenses.append(np.nan)
        cont_income.append(np.nan)
        earned_income.append(np.nan)
        invest_income.append(np.nan)
        pct_compnsatncurrofcr.append(np.nan)
        totassetsend.append(np.nan)
        totliabend.append(np.nan)
        totfuncexpns.append(np.nan)
        yearly_revenue.append(np.nan)
        other_revenue.append(np.nan)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 917/917 [20:16<00:00,  1.33s/it]

# %%
df2 = pd.DataFrame(
    list(zip(company_ein, tax_period, tot_assets, tot_income, tot_revenue, pct_compnsatncurrofcr, tax_year, cont_income, earned_income, invest_income, other_revenue, yearly_revenue, totassetsend, totliabend, totfuncexpns, admin_expenses)),
    columns = ['ein','tax_period', 'total_assets', 'total_income', 'total_revenue', 'pct_exp__current_officers', 'tax_year', 'contributed_income','earned_income','investment_income','other_income','year_end_revenue','year_end_assets', 'year_end_liabilities', 'total_functional_expenses','admin_expenses'])
df2.head(10)
# Out:
#          ein  tax_period  total_assets  total_income  total_revenue  \
# 0  813311094  2019-12-01           0.0           0.0            0.0
# 1  263016871  2018-12-01           0.0           0.0            0.0
# 2  833139772  2019-12-01        1280.0       26521.0        26521.0
# 3  462541609  2018-12-01       12908.0       53745.0        50416.0
# 4  840850527  2018-12-01       12908.0       53745.0        50416.0
#
#    pct_exp__current_officers  tax_year  contributed_income  earned_income  \
# 0                        NaN       NaN                 NaN            NaN
# 1                        NaN       NaN                 NaN            NaN
# 2                        NaN       NaN                 NaN            NaN
# 3                        NaN    2017.0                 NaN            NaN
# 4                        0.0       NaN           2792062.0      1385097.0
#
#    investment_income  other_income  year_end_revenue  year_end_assets  \
# 0                NaN           NaN               NaN              NaN
# 1                NaN           NaN               NaN              NaN
# 2                NaN           NaN               NaN              NaN
# 3                NaN           NaN               NaN              NaN
# 4               91.0        7033.0         4123180.0        2069154.0
#
#    year_end_liabilities  total_functional_expenses  admin_expenses
# 0                   NaN                        NaN             NaN
# 1                   NaN                        NaN             NaN
# 2                   NaN                        NaN             NaN
# 3                   NaN                        NaN             NaN
# 4             2048030.0                  4426594.0        290481.0

# %%
df2.shape
# Out:
# (2428, 16)

# %%
print(len(skipped_requests))
# Out:
# 0

# %%
df2.to_csv('Form 990s.csv')

# %%
df.to_csv('Non-profit entities.csv')
